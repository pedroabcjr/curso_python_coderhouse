# %%
import pandas as pd

# %%
df = pd.read_csv("Cancer_Data.csv",
                 sep = ',',
                 decimal='.')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.loc[df['diagnosis']=='B','diagnosis'].count()
# Out:
# 357

# %%
df['diagnosis'] = df['diagnosis'].str.replace('B','benign cancer')
df['diagnosis'] = df['diagnosis'].str.replace('M','malignant cancer')
df
# Out:
#            id         diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302  malignant cancer        17.99         10.38          122.80
# 1      842517  malignant cancer        20.57         17.77          132.90
# 2    84300903  malignant cancer        19.69         21.25          130.00
# 3    84348301  malignant cancer        11.42         20.38           77.58
# 4    84358402  malignant cancer        20.29         14.34          135.10
# ..        ...               ...          ...           ...             ...
# 564    926424  malignant cancer        21.56         22.39          142.00
# 565    926682  malignant cancer        20.13         28.25          131.20
# 566    926954  malignant cancer        16.60         28.08          108.30
# 567    927241  malignant cancer        20.60         29.33          140.10
# 568     92751     benign cancer         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
df.loc[(df['diagnosis']=="malignant cancer")&(df['radius_mean']>25),'id']
# Out:
# 82       8611555
# 180       873592
# 212      8810703
# 352       899987
# 461    911296202
# Name: id, dtype: int64

# %%
df.loc[(df['diagnosis']=="malignant cancer")&(df['radius_mean']>25),'id']
# Out:
# 82       8611555
# 180       873592
# 212      8810703
# 352       899987
# 461    911296202
# Name: id, dtype: int64

# %% [markdown]
# REVISÃO DE ESTUDOS

# %%
import pandas as pd 

df1 = pd.read_csv('Cancer_Data.csv')

df1.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df2 = pd.read_csv('Cancer_Data.csv',
                 sep = ',',
                 decimal= '.')

# %%
df2
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df2 = pd.read_excel('fastfood.xlsx')

# %%
df2.head()
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat sat_fat            trans_fat  cholesterol  sodium  total_carb  \
# 0          7       2                    0           95    1110          44
# 1         45      17  2023-05-01 00:00:00          130    1580          62
# 2         67      27                    3          220    1920          63
# 3         31      10                  0.5          155    1940          62
# 4         45      12                  0.5          120    1980          81
#
#    fiber  sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
df2_new = df2.set_index('item')

# %%
df2_new
# Out:
#                                           restaurant  calories  cal_fat  \
# item
# Artisan Grilled Chicken Sandwich           Mcdonalds       380       60
# Single Bacon Smokehouse Burger             Mcdonalds       840      410
# Double Bacon Smokehouse Burger             Mcdonalds      1130      600
# Grilled Bacon Smokehouse Chicken Sandwich  Mcdonalds       750      280
# Crispy Bacon Smokehouse Chicken Sandwich   Mcdonalds       920      410
# ...                                              ...       ...      ...
# Spicy Triple Double Crunchwrap             Taco Bell       780      340
# Express Taco Salad w/ Chips                Taco Bell       580      260
# Fiesta Taco Salad-Beef                     Taco Bell       780      380
# Fiesta Taco Salad-Chicken                  Taco Bell       720      320
# Fiesta Taco Salad-Steak                    Taco Bell       720      320
#
#                                            total_fat sat_fat  \
# item
# ...

# %%
df2_new = df2_new.reset_index()

# %%
df2_new
# Out:
#                                           item restaurant  calories  cal_fat  \
# 0             Artisan Grilled Chicken Sandwich  Mcdonalds       380       60
# 1               Single Bacon Smokehouse Burger  Mcdonalds       840      410
# 2               Double Bacon Smokehouse Burger  Mcdonalds      1130      600
# 3    Grilled Bacon Smokehouse Chicken Sandwich  Mcdonalds       750      280
# 4     Crispy Bacon Smokehouse Chicken Sandwich  Mcdonalds       920      410
# ..                                         ...        ...       ...      ...
# 510             Spicy Triple Double Crunchwrap  Taco Bell       780      340
# 511                Express Taco Salad w/ Chips  Taco Bell       580      260
# 512                     Fiesta Taco Salad-Beef  Taco Bell       780      380
# 513                  Fiesta Taco Salad-Chicken  Taco Bell       720      320
# 514                    Fiesta Taco Salad-Steak  Taco Bell       720      320
#
# ...

# %%
df2.columns
# Out:
# Index(['restaurant', 'item', 'calories', 'cal_fat', 'total_fat', 'sat_fat',
#        'trans_fat', 'cholesterol', 'sodium', 'total_carb', 'fiber', 'sugar',
#        'protein', 'vit_a', 'vit_c', 'calcium', 'salad'],
#       dtype='object')

# %%
df2['Variavel_criada'] = 1

# %%
df2.head(2)
# Out:
#   restaurant                              item  calories  cal_fat  total_fat  \
# 0  Mcdonalds  Artisan Grilled Chicken Sandwich       380       60          7
# 1  Mcdonalds    Single Bacon Smokehouse Burger       840      410         45
#
#   sat_fat            trans_fat  cholesterol  sodium  total_carb  fiber  sugar  \
# 0       2                    0           95    1110          44    3.0     11
# 1      17  2023-05-01 00:00:00          130    1580          62    2.0     18
#
#    protein  vit_a  vit_c  calcium  salad  Variavel_crias  Variavel_criada
# 0     37.0    4.0   20.0     20.0  Other               1                1
# 1     46.0    6.0   20.0     20.0  Other               1                1

# %%
df3 = pd.DataFrame({'Nome': ['pedro','carina'], 'idade': [41,33]})

# %%
df3
# Out:
#      Nome  idade
# 0   pedro     41
# 1  carina     33

# %%
df3.columns = ['Name','Years_Old']

df3
# Out:
#      Name  Years_Old
# 0   pedro         41
# 1  carina         33
