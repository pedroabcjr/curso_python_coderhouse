# %%
salario = 3000

# %%
salario * 12
# Out:
# 36000

# %%
nome = 'Joao'
for letra in nome:
    if letra == 'a':
        pass
else:
    print(letra)
# Out:
# o

# %%
a = 12

# %%
condicao = True

# %%
altura = 1.71

# %%
type(altura)
# Out:
# float

# %%
type(a)
# Out:
# int

# %%
type(condicao)
# Out:
# bool

# %%
x = 10
y = 5
z = 3

# %%
soma = x + z
sub = y-y
mult=x*z
div = x/y

# %%
soma = x + z
sub = y-y
mult=x*z

# %%
soma
sub
mult
# Out:
# 30
